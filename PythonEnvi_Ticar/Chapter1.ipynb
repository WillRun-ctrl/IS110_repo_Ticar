# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1
#
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# **Explanation**: There is an error because of the Capital letter "P" and lowercase "f". It should be "print()" instead of "Printf()".

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# **Explanation**: There's a missing open parentheses"(", that is why it errors.

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# **Explanation**: It doesnt have any error on the code itself but it uses lower cases on words.

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# **Explanation**: Has missing apostrophe('). The reason it errors.

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# **Explanation**: It uses more than the desired apostrophe(') that causes the error.

# %% [markdown]
# #### Exercise 2
# What is the output of the code below? [PEW]

# %% [markdown]
# **ANSWER**: 44

# %%
x = 43
x = x + 1
print(x)
# Out:
# 44

# %% [markdown]
# #### Exercise 3
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = x + 1
print(x)
# Out:
# 44

# %% [markdown]
# **Explanation**: It uses uppercase "X" that's why it doesnt match or it say its not defined
